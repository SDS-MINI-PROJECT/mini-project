# %%
# importing the required libraries for various operations:
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import statistics as st
import random

# %%
# weather dataset containing a month's weather data in which data is generated per hour
df=pd.read_csv('weatherHistory.csv')

# %%
# 1. exploratory data analysis

# %%
# a. description of dataset

# %%
# i. displaying the whole dataset
df
# Out:
#                     Formatted Date        Summary Precip Type  \
# 0    2016-09-01 00:00:00.000 +0200          Clear        rain
# 1    2016-09-01 01:00:00.000 +0200          Clear        rain
# 2    2016-09-01 02:00:00.000 +0200          Clear        rain
# 3    2016-09-01 03:00:00.000 +0200          Clear        rain
# 4    2016-09-01 04:00:00.000 +0200          Clear        rain
# 5    2016-09-01 05:00:00.000 +0200          Clear        rain
# 6    2016-09-01 06:00:00.000 +0200          Clear        rain
# 7    2016-09-01 07:00:00.000 +0200  Partly Cloudy        rain
# 8    2016-09-01 08:00:00.000 +0200  Partly Cloudy        rain
# 9    2016-09-01 09:00:00.000 +0200          Clear        rain
# 10   2016-09-01 10:00:00.000 +0200  Partly Cloudy        rain
# 11   2016-09-01 11:00:00.000 +0200  Partly Cloudy        rain
# 12   2016-09-01 12:00:00.000 +0200  Partly Cloudy        rain
# 13   2016-09-01 13:00:00.000 +0200  Partly Cloudy        rain
# 14   2016-09-01 14:00:00.000 +0200  Partly Cloudy        rain
# 15   2016-09-01 15:00:00.000 +0200  Partly Cloudy        rain
# 16   2016-09-01 16:00:00.000 +0200  Partly Cloudy        rain
# 17   2016-09-01 17:00:00.000 +0200  Partly Cloudy        rain
# 18   2016-09-01 18:00:00.000 +0200  Partly Cloudy        rain
# 19   2016-09-01 19:00:00.000 +0200  Partly Cloudy        rain
# 20   2016-09-01 20:00:00.000 +0200  Partly Cloudy        rain
# 21   2016-09-01 21:00:00.000 +0200  Partly Cloudy        rain
# 22   2016-09-01 22:00:00.000 +0200  Partly Cloudy        rain
# 23   2016-09-01 23:00:00.000 +0200  Partly Cloudy        rain
# 24   2016-09-10 00:00:00.000 +0200          Clear        rain
# 25   2016-09-10 01:00:00.000 +0200          Clear        rain
# 26   2016-09-10 02:00:00.000 +0200          Clear        rain
# 27   2016-09-10 03:00:00.000 +0200          Clear        rain
# 28   2016-09-10 04:00:00.000 +0200          Clear        rain
# 29   2016-09-10 05:00:00.000 +0200          Clear        rain
# ..                             ...            ...         ...
# 690  2016-09-08 18:00:00.000 +0200  Partly Cloudy        rain
# 691  2016-09-08 19:00:00.000 +0200  Partly Cloudy        rain
# 692  2016-09-08 20:00:00.000 +0200  Partly Cloudy        rain
# 693  2016-09-08 21:00:00.000 +0200  Mostly Cloudy        rain
# 694  2016-09-08 22:00:00.000 +0200  Partly Cloudy        rain
# 695  2016-09-08 23:00:00.000 +0200  Partly Cloudy        rain
# 696  2016-09-09 00:00:00.000 +0200  Partly Cloudy        rain
# 697  2016-09-09 01:00:00.000 +0200          Clear        rain
# 698  2016-09-09 02:00:00.000 +0200          Clear        rain
# 699  2016-09-09 03:00:00.000 +0200          Clear        rain
# 700  2016-09-09 04:00:00.000 +0200          Clear        rain
# 701  2016-09-09 05:00:00.000 +0200          Clear        rain
# 702  2016-09-09 06:00:00.000 +0200          Clear        rain
# 703  2016-09-09 07:00:00.000 +0200          Clear        rain
# 704  2016-09-09 08:00:00.000 +0200  Partly Cloudy        rain
# 705  2016-09-09 09:00:00.000 +0200  Partly Cloudy        rain
# 706  2016-09-09 10:00:00.000 +0200  Partly Cloudy        rain
# 707  2016-09-09 11:00:00.000 +0200  Partly Cloudy        rain
# 708  2016-09-09 12:00:00.000 +0200  Partly Cloudy        rain
# 709  2016-09-09 13:00:00.000 +0200  Partly Cloudy        rain
# 710  2016-09-09 14:00:00.000 +0200  Partly Cloudy        rain
# 711  2016-09-09 15:00:00.000 +0200  Partly Cloudy        rain
# 712  2016-09-09 16:00:00.000 +0200  Partly Cloudy        rain
# 713  2016-09-09 17:00:00.000 +0200  Partly Cloudy        rain
# 714  2016-09-09 18:00:00.000 +0200  Partly Cloudy        rain
# 715  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 716  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 717  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 718  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 719  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#      Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0          16.344444                 16.344444      0.60             6.1502
# 1          15.788889                 15.788889      0.62             6.1019
# 2          13.344444                 13.344444      0.73             3.2522
# 3          12.611111                 12.611111      0.75             3.2200
# 4          12.038889                 12.038889      0.78             0.0000
# 5          12.122222                 12.122222      0.78             6.4239
# 6          11.994444                 11.994444      0.76             1.6905
# 7          14.661111                 14.661111      0.74             0.0000
# 8          17.461111                 17.461111      0.66             8.8067
# 9          20.994444                 20.994444      0.57             4.8944
# 10         23.816667                 23.816667      0.42             4.3309
# 11               NaN                 24.950000      0.36             8.5491
# 12         26.083333                 26.083333      0.32             7.8085
# 13         27.705556                 26.822222      0.29             7.7441
# 14         27.661111                 26.755556      0.28             8.6779
# 15         27.777778                 26.838889      0.28             4.6368
# 16         28.794444                 27.544444      0.27             9.4990
# 17         27.716667                 26.805556      0.28             9.8210
# 18         27.172222                 26.527778      0.30             8.0983
# 19         23.861111                 23.861111      0.41             4.8300
# 20         20.161111                 20.161111      0.53             0.4830
# 21         17.705556                 17.705556      0.66             0.0000
# 22         17.083333                 17.083333      0.68             6.4400
# 23         16.188889                 16.188889      0.72             4.4597
# 24         17.794444                 17.794444      0.76             6.2468
# 25         17.244444                 17.244444      0.81             6.1502
# 26         17.305556                 17.305556      0.80             5.9892
# 27         16.600000                 16.600000      0.84             6.4400
# 28         16.605556                 16.605556      0.84             6.6493
# 29         16.677778                 16.677778      0.83             6.2307
# ..               ...                       ...       ...                ...
# 690        27.800000                 27.050000      0.32             3.0751
# 691        24.905556                 24.905556      0.51             0.0000
# 692        22.366667                 22.366667      0.58             3.3327
# 693        21.016667                 21.016667      0.64             3.2200
# 694        19.927778                 19.927778      0.71             3.1556
# 695        18.350000                 18.350000      0.77             3.2200
# 696        17.755556                 17.755556      0.81             2.9624
# 697        16.622222                 16.622222      0.87             3.4293
# 698        16.144444                 16.144444      0.87             3.6547
# 699        15.594444                 15.594444      0.87             3.2844
# 700        15.011111                 15.011111      0.93             3.2039
# 717               1015.66             Partly cloudy starting in the morning.
# 718               1015.95             Partly cloudy starting in the morning.
# 719               1016.16             Partly cloudy starting in the morning.
#
# [720 rows x 12 columns]

# %%
# ii. description of dataset

# %%
# iii. meaning of columns in the dataset

# %%
# b. data cleaning

# %%
# i. handling of missing data by dropping:

# %%
# ii. handling of missing data by imputing:

# %%
# iii. handling via the best approach (if different from any of the methods mentioned above):

# %%
# iv. reasons for the above operations

# %%
# c. removal of unwanted observations (duplicate/irrelevant/repetitive)

# %%
# d. fixing of typos and inconsistent capitalization

# %%
# 2. graph visualization

# %%
# a. visualization of dataset to extract meaningful insights

# %%
# b. implementation of graph visualization techniques (any 3) (most suitable)

#number of hours for each summary category

plt.figure(figsize = (20,10))
sns.countplot(df["Summary"])

# %%
# effect of weather on wind speed
plt.figure(figsize = (20,10))
sns.barplot(x = df["Summary"],y = df["Wind Speed (km/h)"])

# %%
#effect of weather on temperature
plt.figure(figsize = (20,10))
sns.barplot(x = df["Summary"],y = df["Temperature (C)"])

# %%
#effect of weather on visibility
plt.figure(figsize = (20,10))
sns.barplot(x = df["Summary"],y = df["Visibility (km)"])

# %%
#effect of weather on humidity

plt.figure(figsize = (20,10))
sns.barplot(x = df["Summary"],y = df["Humidity"])

# %%
#count of daily weather summaries
days = [i for i in range(0,719,24)]
data_with_one_hour_per_day = df.iloc[days,:]

def shorten(text):
    if(text == 'NaN'):
        return text
    return("".join([i[0] for i in text.split(" ")]))

data_with_one_hour_per_day["Daily Summary"] = data_with_one_hour_per_day["Daily Summary"].apply(shorten)

sns.set(font_scale = 1.5)

plt.figure(figsize = (25,15))
p = sns.countplot(data_with_one_hour_per_day["Daily Summary"])
print("Pc = Partly Cloudy , Mc = Mostly Cloudy, F = Foggy, O = Overcast ")
print("sitm = starting in the morning, sita = starting in the afternoon, cun = continuing till noon , cue = continuing till eventing")
print("ttd = throughout the day , so = starting overnight , o = overnight")
# Out:
# /home/justin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# Pc = Partly Cloudy , Mc = Mostly Cloudy, F = Foggy, O = Overcast
# sitm = starting in the morning, sita = starting in the afternoon, cun = continuing till noon , cue = continuing till eventing
# ttd = throughout the day , so = starting overnight , o = overnight

# %%
# c. filtering of unwanted outliers

# %%
# i. via numerical methods (box plot/histogram)
sns.boxplot(df["Wind Speed (km/h)"])

# %%
sns.boxplot(df["Temperature (C)"])

# %%
sns.boxplot(df["Humidity"])

# %%
sns.boxplot(df["Visibility (km)"])

# %%
# ii. categorical (bar chart)

# %%
# 3. normalization and standardization

# %%
# a. mean and variance for each of the columns

# %%
# b. normalization of all the numeric columns (to make mean 0 and variance 1)

# %%
# c. reasons for the neccessity of normalization and the ways in which it affects datasets

# %%
# d. verification of the normality of data by using graphs

# %%
# 4. hypothesis testing

# %%
# a. research hypothesis

# %%
# b. statistical tests

# %%
# c. hypothesis based on columns of our choice

# %%
# d. decision on whether the null hypothesis is supported or rejected

# %%
# 5. correlation

# %%
# a. correlation b/w variables that are positively and negatively related

# %%
# b. inferences
